# %% [markdown]
# ### Exercise 2

# %%
# Loop for '*' patterns: square
# Use nested for loops
n = 5
for i in range(n):
    for j in range(i+1):
        print('*', end='  ')
    print()
# Out:
# *
# *  *
# *  *  *
# *  *  *  *
# *  *  *  *  *
